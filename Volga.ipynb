# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from _plotly_future_ import v4_subplots
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import pickle
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# parameter settings
S_min   = 50          # lower bound for the asset price
S_max   = 150         # upper bound for the asset price
Tau_min = 0.01        # lower bound for time to maturity
Tau_max = 1           # upper bound for time to maturity
K       = 100         # strike price
r       = 0.1         # risk-free interest rate                  
sig     = 0.85        # volatility               
d       = 0.2         # dividend rate                
steps   = 60          # steps

# %%
def calculate_volga(S,K,r,d,Tau,sig):
    d1 = (np.log(S/K) + (r-d+sig**2/2) * Tau) / (sig*np.sqrt(Tau))
    d2 = d1 - sig*np.sqrt(Tau)
    vega = np.exp(-d*Tau) * S * np.sqrt(Tau) * norm.pdf(d1)
    return vega * (d1*d2/sig)

# %%
# Volga surface
Volga = np.zeros([steps, steps])

# space partitioning
Tau_grid = np.arange(Tau_min, Tau_max+0.01, (Tau_max-Tau_min)/(steps-1))
S_grid = np.arange(S_min, S_max+0.01, (S_max-S_min)/(steps-1))

for i, S in enumerate(S_grid):
    for j, Tau in enumerate(Tau_grid):
        Volga[i][j] = calculate_volga(S, K, r, d, Tau, sig)

# %%
layout = go.Layout(title='Volga as function of the time to maturity and the asset price', 
                   scene = dict(xaxis_title = 'Tau', yaxis_title = 'S', zaxis_title = 'Volga', 
                                camera_eye = dict(x=-1.6, y=-1.6, z=0.7)))

fig = go.Figure(data=[go.Surface(z=Volga, x=Tau_grid, y=S_grid)], layout=layout)

# interactive plot
iplot(fig)

plot(fig, filename='Volga.html')
# Out:
# <div>
#
#
#             <div id="9a943599-684c-45ec-8218-750e47d7b3bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9a943599-684c-45ec-8218-750e47d7b3bb")) {
#                     Plotly.newPlot(
#                         '9a943599-684c-45ec-8218-750e47d7b3bb',
#                         [{"type": "surface", "x": [0.01, 0.026779661016949154, 0.043559322033898305, 0.06033898305084746, 0.0771186440677966, 0.09389830508474575, 0.1106779661016949, 0.12745762711864406, 0.14423728813559322, 0.1610169491525424, 0.17779661016949153, 0.19457627118644066, 0.21135593220338983, 0.228135593220339, 0.24491525423728813, 0.26169491525423727, 0.27847457627118644, 0.2952542372881356, 0.31203389830508477, 0.3288135593220339, 0.34559322033898304, 0.3623728813559322, 0.3791525423728813, 0.3959322033898305, 0.41271186440677965, 0.4294915254237288, 0.446271186440678, 0.4630508474576271, 0.47983050847457626, 0.4966101694915254, 0.5133898305084745, 0.5301694915254237, 0.5469491525423729, 0.563728813559322, 0.5805084745762712, 0.5972881355932204, 0.6140677966101695, 0.6308474576271186, 0.6476271186440677, 0.6644067796610169, 0.6811864406779661, 0.6979661016949152, 0.7147457627118644, 0.7315254237288136, 0.7483050847457626, 0.7650847457627118, 0.781864406779661, 0.7986440677966101, 0.8154237288135593, 0.8322033898305085, 0.8489830508474576, 0.8657627118